# %%
import mysql.connector

conn = mysql.connector.connect(
    host='127.0.0.1',
    user='root',
    password='Jnm241123@',
    database='ola_project',
    allow_local_infile=True
)
cur = conn.cursor()

# ✅ Use LOCAL
sql = r"""
LOAD DATA LOCAL INFILE 'C:/Users/achsa/Documents/LABMENTIX/PROJECT 12 28_09_25/project/output/ola_clean.csv'
INTO TABLE ola_clean
CHARACTER SET utf8mb4
FIELDS TERMINATED BY ','
OPTIONALLY ENCLOSED BY '"'
LINES TERMINATED BY '\r\n'
IGNORE 1 LINES
(`Date`,`Time`,`ride_id`,`status`,`customer_id`,`vehicle_type`,`Pickup_Location`,`Drop_Location`,
 `V_TAT`,`C_TAT`,`Canceled_Rides_by_Customer`,`Canceled_Rides_by_Driver`,`Incomplete_Rides`,
 `Incomplete_Rides_Reason`,`total_amount`,`payment_method`,`distance_km`,`Driver_Ratings`,
 `customer_rating`,`Vehicle Images`,`ride_duration_min`,`status_norm`,`is_completed`,`cancelled_by_norm`);
"""
cur.execute(sql)
conn.commit()
cur.close()
conn.close()
print("✅ Done: CSV loaded into MySQL")
# Out:
# ✅ Done: CSV loaded into MySQL
